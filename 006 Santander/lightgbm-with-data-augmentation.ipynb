# %% [markdown]
# Big thanks to Jiwei Liu for Augment insight!
# https://www.kaggle.com/jiweiliu/lgb-2-leaves-augment

# %%
import lightgbm as lgb
import pandas as pd
import numpy as np

from datetime import datetime
from pathlib import Path
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RepeatedStratifiedKFold

# %%
path=Path("../input/")
train=pd.read_csv(path/"train.csv").drop("ID_code",axis=1)
test=pd.read_csv(path/"test.csv").drop("ID_code",axis=1)

# %%
## Inspiration from
#https://www.kaggle.com/jiweiliu/lgb-2-leaves-augment
def augment(train,num_n=1,num_p=2):
    newtrain=[train]
    
    n=train[train.target==0]
    for i in range(num_n):
        newtrain.append(n.apply(lambda x:x.values.take(np.random.permutation(len(n)))))
    
    for i in range(num_p):
        p=train[train.target>0]
        newtrain.append(p.apply(lambda x:x.values.take(np.random.permutation(len(p)))))
    return pd.concat(newtrain)
#df=oversample(train,2,1)

# %%
param = {
   "objective" : "binary",
    "metric" : "auc",
    "boosting": 'gbdt',
    "max_depth" : -1,
    "num_leaves" : 13,
    "learning_rate" : 0.01,
    "bagging_freq": 5,
    "bagging_fraction" : 0.4,
    "feature_fraction" : 0.05,
    "min_data_in_leaf": 80,
    "min_sum_heassian_in_leaf": 10,
    "tree_learner": "serial",
    "boost_from_average": "false",
    "bagging_seed" : 10,
    "verbosity" : 1,
}

# %%
result=np.zeros(test.shape[0])

rskf = RepeatedStratifiedKFold(n_splits=5, n_repeats=5,random_state=10)
for counter,(train_index, valid_index) in enumerate(rskf.split(train, train.target),1):
    print (counter)
    
    #Train data
    t=train.iloc[train_index]
    t=augment(t)
    trn_data = lgb.Dataset(t.drop("target",axis=1), label=t.target)
    
    #Validation data
    v=train.iloc[valid_index]
    val_data = lgb.Dataset(v.drop("target",axis=1), label=v.target)
    
    #Training
    model = lgb.train(param, trn_data, 1000000, valid_sets = [val_data], verbose_eval=500, early_stopping_rounds = 3000)
    result +=model.predict(test)
# Out:
# 1
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.871645
# [1000]	valid_0's auc: 0.879196
# [1500]	valid_0's auc: 0.883934
# [2000]	valid_0's auc: 0.887401
# [2500]	valid_0's auc: 0.889815
# [3000]	valid_0's auc: 0.892204
# [3500]	valid_0's auc: 0.893881
# [4000]	valid_0's auc: 0.895249
# [4500]	valid_0's auc: 0.896443
# [5000]	valid_0's auc: 0.897381
# [5500]	valid_0's auc: 0.897987
# [6000]	valid_0's auc: 0.898546
# [6500]	valid_0's auc: 0.898883
# [7000]	valid_0's auc: 0.899172
# [7500]	valid_0's auc: 0.899328
# [8000]	valid_0's auc: 0.899543
# [8500]	valid_0's auc: 0.899719
# [9000]	valid_0's auc: 0.899862
# [9500]	valid_0's auc: 0.899945
# [10000]	valid_0's auc: 0.899972
# [10500]	valid_0's auc: 0.900033
# [11000]	valid_0's auc: 0.900119
# [11500]	valid_0's auc: 0.900128
# [12000]	valid_0's auc: 0.900183
# [12500]	valid_0's auc: 0.900143
# [13000]	valid_0's auc: 0.900156
# [13500]	valid_0's auc: 0.900127
# [14000]	valid_0's auc: 0.900079
# [14500]	valid_0's auc: 0.900055
# [15000]	valid_0's auc: 0.899985
# Early stopping, best iteration is:
# [12020]	valid_0's auc: 0.900198
# 2
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.870991
# [1000]	valid_0's auc: 0.879032
# [1500]	valid_0's auc: 0.883924
# [2000]	valid_0's auc: 0.887948
# [2500]	valid_0's auc: 0.89076
# [3000]	valid_0's auc: 0.893095
# [3500]	valid_0's auc: 0.894885
# [4000]	valid_0's auc: 0.896242
# [4500]	valid_0's auc: 0.897217
# [5000]	valid_0's auc: 0.898153
# [5500]	valid_0's auc: 0.898808
# [6000]	valid_0's auc: 0.899297
# [6500]	valid_0's auc: 0.89961
# [7000]	valid_0's auc: 0.899821
# [7500]	valid_0's auc: 0.899998
# [8000]	valid_0's auc: 0.900137
# [8500]	valid_0's auc: 0.900226
# [9000]	valid_0's auc: 0.900284
# [9500]	valid_0's auc: 0.900363
# [10000]	valid_0's auc: 0.900353
# [10500]	valid_0's auc: 0.900343
# [11000]	valid_0's auc: 0.900326
# [11500]	valid_0's auc: 0.900347
# [12000]	valid_0's auc: 0.900306
# [12500]	valid_0's auc: 0.900223
# [13000]	valid_0's auc: 0.900094
# Early stopping, best iteration is:
# [10080]	valid_0's auc: 0.900409
# 3
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.874669
# [1000]	valid_0's auc: 0.882374
# [1500]	valid_0's auc: 0.887317
# [2000]	valid_0's auc: 0.890979
# [2500]	valid_0's auc: 0.893851
# [3000]	valid_0's auc: 0.896048
# [3500]	valid_0's auc: 0.897798
# [4000]	valid_0's auc: 0.899025
# [4500]	valid_0's auc: 0.900037
# [5000]	valid_0's auc: 0.90083
# [5500]	valid_0's auc: 0.901282
# [6000]	valid_0's auc: 0.901635
# [6500]	valid_0's auc: 0.901982
# [7000]	valid_0's auc: 0.902247
# [7500]	valid_0's auc: 0.902426
# [8000]	valid_0's auc: 0.902504
# [8500]	valid_0's auc: 0.902534
# [9000]	valid_0's auc: 0.902641
# [9500]	valid_0's auc: 0.902699
# [10000]	valid_0's auc: 0.90266
# [10500]	valid_0's auc: 0.902706
# [11000]	valid_0's auc: 0.902659
# [11500]	valid_0's auc: 0.902636
# [12000]	valid_0's auc: 0.902587
# Early stopping, best iteration is:
# [9424]	valid_0's auc: 0.90272
# 4
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.868193
# [1000]	valid_0's auc: 0.87604
# [1500]	valid_0's auc: 0.880899
# [2000]	valid_0's auc: 0.884237
# [2500]	valid_0's auc: 0.886945
# [3000]	valid_0's auc: 0.888907
# [3500]	valid_0's auc: 0.890323
# [4000]	valid_0's auc: 0.891787
# [4500]	valid_0's auc: 0.892714
# [5000]	valid_0's auc: 0.893519
# [5500]	valid_0's auc: 0.894134
# [6000]	valid_0's auc: 0.894672
# [6500]	valid_0's auc: 0.895016
# [7000]	valid_0's auc: 0.8954
# [7500]	valid_0's auc: 0.89572
# [8000]	valid_0's auc: 0.895842
# [8500]	valid_0's auc: 0.896014
# [9000]	valid_0's auc: 0.89618
# [9500]	valid_0's auc: 0.896204
# [10000]	valid_0's auc: 0.896271
# [10500]	valid_0's auc: 0.896334
# [11000]	valid_0's auc: 0.896361
# [11500]	valid_0's auc: 0.896437
# [12000]	valid_0's auc: 0.896473
# [12500]	valid_0's auc: 0.896435
# [13000]	valid_0's auc: 0.896453
# [13500]	valid_0's auc: 0.896463
# [14000]	valid_0's auc: 0.896425
# [14500]	valid_0's auc: 0.896379
# [15000]	valid_0's auc: 0.896322
# Early stopping, best iteration is:
# [12230]	valid_0's auc: 0.896483
# 5
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.877863
# [1000]	valid_0's auc: 0.885489
# [1500]	valid_0's auc: 0.890149
# [2000]	valid_0's auc: 0.893643
# [2500]	valid_0's auc: 0.896242
# [3000]	valid_0's auc: 0.898113
# [3500]	valid_0's auc: 0.899629
# [4000]	valid_0's auc: 0.900873
# [4500]	valid_0's auc: 0.901897
# [5000]	valid_0's auc: 0.902587
# [5500]	valid_0's auc: 0.903156
# [6000]	valid_0's auc: 0.903669
# [6500]	valid_0's auc: 0.904075
# [7000]	valid_0's auc: 0.904328
# [7500]	valid_0's auc: 0.904588
# [8000]	valid_0's auc: 0.904683
# [8500]	valid_0's auc: 0.904842
# [9000]	valid_0's auc: 0.904891
# [9500]	valid_0's auc: 0.904899
# [10000]	valid_0's auc: 0.904964
# [10500]	valid_0's auc: 0.905022
# [11000]	valid_0's auc: 0.905049
# [11500]	valid_0's auc: 0.90501
# [12000]	valid_0's auc: 0.90492
# [12500]	valid_0's auc: 0.904861
# [13000]	valid_0's auc: 0.904803
# [13500]	valid_0's auc: 0.904801
# Early stopping, best iteration is:
# [10892]	valid_0's auc: 0.905087
# 6
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.879028
# [1000]	valid_0's auc: 0.886078
# [1500]	valid_0's auc: 0.890265
# [2000]	valid_0's auc: 0.893373
# [2500]	valid_0's auc: 0.895723
# [3000]	valid_0's auc: 0.897857
# [3500]	valid_0's auc: 0.899434
# [4000]	valid_0's auc: 0.900702
# [4500]	valid_0's auc: 0.901727
# [5000]	valid_0's auc: 0.902439
# [5500]	valid_0's auc: 0.902965
# [6000]	valid_0's auc: 0.903354
# [6500]	valid_0's auc: 0.903682
# [7000]	valid_0's auc: 0.904051
# [7500]	valid_0's auc: 0.904205
# [8000]	valid_0's auc: 0.904349
# [8500]	valid_0's auc: 0.904405
# [9000]	valid_0's auc: 0.904496
# [9500]	valid_0's auc: 0.904592
# [10000]	valid_0's auc: 0.904618
# [10500]	valid_0's auc: 0.904725
# [11000]	valid_0's auc: 0.904755
# [11500]	valid_0's auc: 0.904756
# [12000]	valid_0's auc: 0.904784
# [12500]	valid_0's auc: 0.904729
# [13000]	valid_0's auc: 0.904728
# [13500]	valid_0's auc: 0.904678
# [14000]	valid_0's auc: 0.90467
# [14500]	valid_0's auc: 0.904704
# Early stopping, best iteration is:
# [11607]	valid_0's auc: 0.904806
# 7
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.867674
# [1000]	valid_0's auc: 0.875154
# [1500]	valid_0's auc: 0.880017
# [2000]	valid_0's auc: 0.88378
# [2500]	valid_0's auc: 0.886788
# [3000]	valid_0's auc: 0.889199
# [3500]	valid_0's auc: 0.89102
# [4000]	valid_0's auc: 0.892457
# [4500]	valid_0's auc: 0.893596
# [5000]	valid_0's auc: 0.894469
# [5500]	valid_0's auc: 0.895112
# [6000]	valid_0's auc: 0.895623
# [6500]	valid_0's auc: 0.896066
# [7000]	valid_0's auc: 0.896369
# [7500]	valid_0's auc: 0.896576
# [8000]	valid_0's auc: 0.896754
# [8500]	valid_0's auc: 0.896796
# [9000]	valid_0's auc: 0.896837
# [9500]	valid_0's auc: 0.896888
# [10000]	valid_0's auc: 0.89692
# [10500]	valid_0's auc: 0.896935
# [11000]	valid_0's auc: 0.896976
# [11500]	valid_0's auc: 0.897045
# [12000]	valid_0's auc: 0.896971
# [12500]	valid_0's auc: 0.897007
# [13000]	valid_0's auc: 0.896975
# [13500]	valid_0's auc: 0.896925
# [14000]	valid_0's auc: 0.896909
# [14500]	valid_0's auc: 0.896876
# Early stopping, best iteration is:
# [11564]	valid_0's auc: 0.897061
# 8
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.874439
# [1000]	valid_0's auc: 0.882518
# [1500]	valid_0's auc: 0.887097
# [2000]	valid_0's auc: 0.890753
# [2500]	valid_0's auc: 0.893354
# [3000]	valid_0's auc: 0.895367
# [3500]	valid_0's auc: 0.896779
# [4000]	valid_0's auc: 0.898017
# [4500]	valid_0's auc: 0.89911
# [5000]	valid_0's auc: 0.899888
# [5500]	valid_0's auc: 0.900465
# [6000]	valid_0's auc: 0.900857
# [6500]	valid_0's auc: 0.901091
# [7000]	valid_0's auc: 0.901302
# [7500]	valid_0's auc: 0.901565
# [8000]	valid_0's auc: 0.901703
# [8500]	valid_0's auc: 0.90179
# [9000]	valid_0's auc: 0.901858
# [9500]	valid_0's auc: 0.901883
# [10000]	valid_0's auc: 0.901786
# [10500]	valid_0's auc: 0.901864
# [11000]	valid_0's auc: 0.90185
# [11500]	valid_0's auc: 0.901942
# [12000]	valid_0's auc: 0.901837
# [12500]	valid_0's auc: 0.901836
# [13000]	valid_0's auc: 0.901799
# [13500]	valid_0's auc: 0.901751
# [14000]	valid_0's auc: 0.901717
# Early stopping, best iteration is:
# [11466]	valid_0's auc: 0.901955
# 9
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.8746
# [1000]	valid_0's auc: 0.882848
# [1500]	valid_0's auc: 0.887871
# [2000]	valid_0's auc: 0.891586
# [2500]	valid_0's auc: 0.894238
# [3000]	valid_0's auc: 0.896354
# [3500]	valid_0's auc: 0.897965
# [4000]	valid_0's auc: 0.899365
# [4500]	valid_0's auc: 0.900273
# [5000]	valid_0's auc: 0.900968
# [5500]	valid_0's auc: 0.9017
# [6000]	valid_0's auc: 0.9022
# [6500]	valid_0's auc: 0.902595
# [7000]	valid_0's auc: 0.902805
# [7500]	valid_0's auc: 0.903039
# [8000]	valid_0's auc: 0.903113
# [8500]	valid_0's auc: 0.903188
# [9000]	valid_0's auc: 0.903284
# [9500]	valid_0's auc: 0.903351
# [10000]	valid_0's auc: 0.903336
# [10500]	valid_0's auc: 0.903362
# [11000]	valid_0's auc: 0.903415
# [11500]	valid_0's auc: 0.90344
# [12000]	valid_0's auc: 0.903418
# [12500]	valid_0's auc: 0.90336
# [13000]	valid_0's auc: 0.903327
# [13500]	valid_0's auc: 0.903282
# [14000]	valid_0's auc: 0.903189
# [14500]	valid_0's auc: 0.903104
# Early stopping, best iteration is:
# [11774]	valid_0's auc: 0.903466
# 10
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.868773
# [1000]	valid_0's auc: 0.87618
# [1500]	valid_0's auc: 0.880798
# [2000]	valid_0's auc: 0.884531
# [2500]	valid_0's auc: 0.887164
# [3000]	valid_0's auc: 0.889539
# [3500]	valid_0's auc: 0.891327
# [4000]	valid_0's auc: 0.892699
# [4500]	valid_0's auc: 0.893817
# [5000]	valid_0's auc: 0.894694
# [5500]	valid_0's auc: 0.895431
# [6000]	valid_0's auc: 0.895959
# [6500]	valid_0's auc: 0.896333
# [7000]	valid_0's auc: 0.896609
# [7500]	valid_0's auc: 0.896863
# [8000]	valid_0's auc: 0.896971
# [8500]	valid_0's auc: 0.897061
# [9000]	valid_0's auc: 0.897181
# [9500]	valid_0's auc: 0.897246
# [10000]	valid_0's auc: 0.89724
# [10500]	valid_0's auc: 0.897233
# [11000]	valid_0's auc: 0.897278
# [11500]	valid_0's auc: 0.897292
# [12000]	valid_0's auc: 0.897343
# [12500]	valid_0's auc: 0.89735
# [13000]	valid_0's auc: 0.897378
# [13500]	valid_0's auc: 0.89738
# [14000]	valid_0's auc: 0.897366
# [14500]	valid_0's auc: 0.897288
# [15000]	valid_0's auc: 0.897229
# [15500]	valid_0's auc: 0.897156
# [16000]	valid_0's auc: 0.897171
# Early stopping, best iteration is:
# [13245]	valid_0's auc: 0.897429
# 11
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.869598
# [1000]	valid_0's auc: 0.877816
# [1500]	valid_0's auc: 0.882391
# [2000]	valid_0's auc: 0.885548
# [2500]	valid_0's auc: 0.887969
# [3000]	valid_0's auc: 0.889966
# [3500]	valid_0's auc: 0.891679
# [4000]	valid_0's auc: 0.893042
# [4500]	valid_0's auc: 0.894033
# [5000]	valid_0's auc: 0.894783
# [5500]	valid_0's auc: 0.89539
# [6000]	valid_0's auc: 0.895884
# [6500]	valid_0's auc: 0.896186
# [7000]	valid_0's auc: 0.896396
# [7500]	valid_0's auc: 0.896617
# [8000]	valid_0's auc: 0.896794
# [8500]	valid_0's auc: 0.896948
# [9000]	valid_0's auc: 0.896985
# [9500]	valid_0's auc: 0.896996
# [10000]	valid_0's auc: 0.89696
# [10500]	valid_0's auc: 0.897112
# [11000]	valid_0's auc: 0.897178
# [11500]	valid_0's auc: 0.897165
# [12000]	valid_0's auc: 0.897147
# [12500]	valid_0's auc: 0.897065
# [13000]	valid_0's auc: 0.897014
# [13500]	valid_0's auc: 0.897008
# [14000]	valid_0's auc: 0.897033
# Early stopping, best iteration is:
# [11231]	valid_0's auc: 0.897208
# 12
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.872148
# [1000]	valid_0's auc: 0.879481
# [1500]	valid_0's auc: 0.884049
# [2000]	valid_0's auc: 0.88812
# [2500]	valid_0's auc: 0.890744
# [3000]	valid_0's auc: 0.892942
# [3500]	valid_0's auc: 0.894734
# [4000]	valid_0's auc: 0.896132
# [4500]	valid_0's auc: 0.897191
# [5000]	valid_0's auc: 0.898002
# [5500]	valid_0's auc: 0.89866
# [6000]	valid_0's auc: 0.899181
# [6500]	valid_0's auc: 0.899575
# [7000]	valid_0's auc: 0.899785
# [7500]	valid_0's auc: 0.900076
# [8000]	valid_0's auc: 0.900295
# [8500]	valid_0's auc: 0.90048
# [9000]	valid_0's auc: 0.900527
# [9500]	valid_0's auc: 0.900604
# [10000]	valid_0's auc: 0.900648
# [10500]	valid_0's auc: 0.900615
# [11000]	valid_0's auc: 0.90066
# [11500]	valid_0's auc: 0.900624
# [12000]	valid_0's auc: 0.900596
# [12500]	valid_0's auc: 0.90056
# [13000]	valid_0's auc: 0.900614
# [13500]	valid_0's auc: 0.900627
# Early stopping, best iteration is:
# [10980]	valid_0's auc: 0.900667
# 13
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.872938
# [1000]	valid_0's auc: 0.881092
# [1500]	valid_0's auc: 0.885396
# [2000]	valid_0's auc: 0.888927
# [2500]	valid_0's auc: 0.891672
# [3000]	valid_0's auc: 0.893768
# [3500]	valid_0's auc: 0.89533
# [4000]	valid_0's auc: 0.896637
# [4500]	valid_0's auc: 0.897692
# [5000]	valid_0's auc: 0.898516
# [5500]	valid_0's auc: 0.899128
# [6000]	valid_0's auc: 0.899591
# [6500]	valid_0's auc: 0.899927
# [7000]	valid_0's auc: 0.900245
# [7500]	valid_0's auc: 0.900401
# [8000]	valid_0's auc: 0.900707
# [8500]	valid_0's auc: 0.900784
# [9000]	valid_0's auc: 0.900827
# [9500]	valid_0's auc: 0.900849
# [10000]	valid_0's auc: 0.900881
# [10500]	valid_0's auc: 0.900852
# [11000]	valid_0's auc: 0.900768
# [11500]	valid_0's auc: 0.900769
# [12000]	valid_0's auc: 0.90078
# [12500]	valid_0's auc: 0.900808
# Early stopping, best iteration is:
# [9740]	valid_0's auc: 0.900884
# 14
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.875436
# [1000]	valid_0's auc: 0.883112
# [1500]	valid_0's auc: 0.887925
# [2000]	valid_0's auc: 0.891426
# [2500]	valid_0's auc: 0.893947
# [3000]	valid_0's auc: 0.896273
# [3500]	valid_0's auc: 0.897744
# [4000]	valid_0's auc: 0.898951
# [4500]	valid_0's auc: 0.899878
# [5000]	valid_0's auc: 0.900606
# [5500]	valid_0's auc: 0.901154
# [6000]	valid_0's auc: 0.901526
# [6500]	valid_0's auc: 0.901834
# [7000]	valid_0's auc: 0.902121
# [7500]	valid_0's auc: 0.90226
# [8000]	valid_0's auc: 0.902413
# [8500]	valid_0's auc: 0.902421
# [9000]	valid_0's auc: 0.90251
# [9500]	valid_0's auc: 0.902503
# [10000]	valid_0's auc: 0.902517
# [10500]	valid_0's auc: 0.902526
# [11000]	valid_0's auc: 0.902539
# [11500]	valid_0's auc: 0.902456
# [12000]	valid_0's auc: 0.902414
# [12500]	valid_0's auc: 0.90237
# [13000]	valid_0's auc: 0.902262
# [13500]	valid_0's auc: 0.902247
# Early stopping, best iteration is:
# [10722]	valid_0's auc: 0.902566
# 15
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.873689
# [1000]	valid_0's auc: 0.881778
# [1500]	valid_0's auc: 0.886566
# [2000]	valid_0's auc: 0.89023
# [2500]	valid_0's auc: 0.892959
# [3000]	valid_0's auc: 0.895523
# [3500]	valid_0's auc: 0.897323
# [4000]	valid_0's auc: 0.898668
# [4500]	valid_0's auc: 0.899881
# [5000]	valid_0's auc: 0.900713
# [5500]	valid_0's auc: 0.901398
# [6000]	valid_0's auc: 0.901936
# [6500]	valid_0's auc: 0.902221
# [7000]	valid_0's auc: 0.902619
# [7500]	valid_0's auc: 0.902912
# [8000]	valid_0's auc: 0.903132
# [8500]	valid_0's auc: 0.903314
# [9000]	valid_0's auc: 0.903403
# [9500]	valid_0's auc: 0.9035
# [10000]	valid_0's auc: 0.903594
# [10500]	valid_0's auc: 0.90362
# [11000]	valid_0's auc: 0.903638
# [11500]	valid_0's auc: 0.903609
# [12000]	valid_0's auc: 0.903594
# [12500]	valid_0's auc: 0.903602
# [13000]	valid_0's auc: 0.90359
# [13500]	valid_0's auc: 0.90354
# Early stopping, best iteration is:
# [10914]	valid_0's auc: 0.903663
# 16
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.873487
# [1000]	valid_0's auc: 0.881985
# [1500]	valid_0's auc: 0.886148
# [2000]	valid_0's auc: 0.88966
# [2500]	valid_0's auc: 0.892021
# [3000]	valid_0's auc: 0.89399
# [3500]	valid_0's auc: 0.895338
# [4000]	valid_0's auc: 0.896608
# [4500]	valid_0's auc: 0.89753
# [5000]	valid_0's auc: 0.898336
# [5500]	valid_0's auc: 0.898874
# [6000]	valid_0's auc: 0.899353
# [6500]	valid_0's auc: 0.89963
# [7000]	valid_0's auc: 0.899936
# [7500]	valid_0's auc: 0.900114
# [8000]	valid_0's auc: 0.900264
# [8500]	valid_0's auc: 0.900389
# [9000]	valid_0's auc: 0.900442
# [9500]	valid_0's auc: 0.90048
# [10000]	valid_0's auc: 0.900495
# [10500]	valid_0's auc: 0.900477
# [11000]	valid_0's auc: 0.900412
# [11500]	valid_0's auc: 0.900416
# [12000]	valid_0's auc: 0.90042
# [12500]	valid_0's auc: 0.90035
# Early stopping, best iteration is:
# [9717]	valid_0's auc: 0.900541
# 17
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.87291
# [1000]	valid_0's auc: 0.879886
# [1500]	valid_0's auc: 0.884191
# [2000]	valid_0's auc: 0.887764
# [2500]	valid_0's auc: 0.89041
# [3000]	valid_0's auc: 0.892717
# [3500]	valid_0's auc: 0.894511
# [4000]	valid_0's auc: 0.895967
# [4500]	valid_0's auc: 0.897073
# [5000]	valid_0's auc: 0.897987
# [5500]	valid_0's auc: 0.89873
# [6000]	valid_0's auc: 0.899307
# [6500]	valid_0's auc: 0.899713
# [7000]	valid_0's auc: 0.900071
# [7500]	valid_0's auc: 0.900303
# [8000]	valid_0's auc: 0.900454
# [8500]	valid_0's auc: 0.900569
# [9000]	valid_0's auc: 0.900692
# [9500]	valid_0's auc: 0.9007
# [10000]	valid_0's auc: 0.900786
# [10500]	valid_0's auc: 0.900862
# [11000]	valid_0's auc: 0.900932
# [11500]	valid_0's auc: 0.900945
# [12000]	valid_0's auc: 0.900948
# [12500]	valid_0's auc: 0.900945
# [13000]	valid_0's auc: 0.900942
# [13500]	valid_0's auc: 0.900864
# [14000]	valid_0's auc: 0.900815
# [14500]	valid_0's auc: 0.900849
# [15000]	valid_0's auc: 0.900884
# Early stopping, best iteration is:
# [12294]	valid_0's auc: 0.900977
# 18
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.87153
# [1000]	valid_0's auc: 0.87895
# [1500]	valid_0's auc: 0.883682
# [2000]	valid_0's auc: 0.887326
# [2500]	valid_0's auc: 0.889993
# [3000]	valid_0's auc: 0.892287
# [3500]	valid_0's auc: 0.893912
# [4000]	valid_0's auc: 0.895251
# [4500]	valid_0's auc: 0.896322
# [5000]	valid_0's auc: 0.897028
# [5500]	valid_0's auc: 0.897664
# [6000]	valid_0's auc: 0.898132
# [6500]	valid_0's auc: 0.89854
# [7000]	valid_0's auc: 0.898906
# [7500]	valid_0's auc: 0.899038
# [8000]	valid_0's auc: 0.899166
# [8500]	valid_0's auc: 0.899229
# [9000]	valid_0's auc: 0.89921
# [9500]	valid_0's auc: 0.899328
# [10000]	valid_0's auc: 0.899355
# [10500]	valid_0's auc: 0.899346
# [11000]	valid_0's auc: 0.899274
# [11500]	valid_0's auc: 0.899255
# [12000]	valid_0's auc: 0.899233
# [12500]	valid_0's auc: 0.899231
# Early stopping, best iteration is:
# [9681]	valid_0's auc: 0.899386
# 19
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.871977
# [1000]	valid_0's auc: 0.879957
# [1500]	valid_0's auc: 0.88481
# [2000]	valid_0's auc: 0.888634
# [2500]	valid_0's auc: 0.891008
# [3000]	valid_0's auc: 0.893382
# [3500]	valid_0's auc: 0.894864
# [4000]	valid_0's auc: 0.896164
# [4500]	valid_0's auc: 0.897236
# [5000]	valid_0's auc: 0.89794
# [5500]	valid_0's auc: 0.898586
# [6000]	valid_0's auc: 0.899072
# [6500]	valid_0's auc: 0.899447
# [7000]	valid_0's auc: 0.899809
# [7500]	valid_0's auc: 0.900036
# [8000]	valid_0's auc: 0.900141
# [8500]	valid_0's auc: 0.900281
# [9000]	valid_0's auc: 0.900364
# [9500]	valid_0's auc: 0.900477
# [10000]	valid_0's auc: 0.900538
# [10500]	valid_0's auc: 0.900593
# [11000]	valid_0's auc: 0.900582
# [11500]	valid_0's auc: 0.900581
# [12000]	valid_0's auc: 0.900578
# [12500]	valid_0's auc: 0.900605
# [13000]	valid_0's auc: 0.900585
# [13500]	valid_0's auc: 0.900571
# [14000]	valid_0's auc: 0.900584
# [14500]	valid_0's auc: 0.900533
# [15000]	valid_0's auc: 0.900483
# Early stopping, best iteration is:
# [12388]	valid_0's auc: 0.900636
# 20
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.872715
# [1000]	valid_0's auc: 0.881743
# [1500]	valid_0's auc: 0.886863
# [2000]	valid_0's auc: 0.890691
# [2500]	valid_0's auc: 0.893434
# [3000]	valid_0's auc: 0.89539
# [3500]	valid_0's auc: 0.896833
# [4000]	valid_0's auc: 0.898183
# [4500]	valid_0's auc: 0.899366
# [5000]	valid_0's auc: 0.900174
# [5500]	valid_0's auc: 0.900798
# [6000]	valid_0's auc: 0.901355
# [6500]	valid_0's auc: 0.901828
# [7000]	valid_0's auc: 0.902098
# [7500]	valid_0's auc: 0.90224
# [8000]	valid_0's auc: 0.9024
# [8500]	valid_0's auc: 0.902484
# [9000]	valid_0's auc: 0.902599
# [9500]	valid_0's auc: 0.90262
# [10000]	valid_0's auc: 0.902673
# [10500]	valid_0's auc: 0.902695
# [11000]	valid_0's auc: 0.902685
# [11500]	valid_0's auc: 0.902666
# [12000]	valid_0's auc: 0.90257
# [12500]	valid_0's auc: 0.902516
# [13000]	valid_0's auc: 0.902442
# Early stopping, best iteration is:
# [10303]	valid_0's auc: 0.90271
# 21
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.872353
# [1000]	valid_0's auc: 0.880024
# [1500]	valid_0's auc: 0.884704
# [2000]	valid_0's auc: 0.888673
# [2500]	valid_0's auc: 0.891194
# [3000]	valid_0's auc: 0.893655
# [3500]	valid_0's auc: 0.895406
# [4000]	valid_0's auc: 0.896648
# [4500]	valid_0's auc: 0.897607
# [5000]	valid_0's auc: 0.898441
# [5500]	valid_0's auc: 0.89913
# [6000]	valid_0's auc: 0.899616
# [6500]	valid_0's auc: 0.900024
# [7000]	valid_0's auc: 0.900329
# [7500]	valid_0's auc: 0.900532
# [8000]	valid_0's auc: 0.900638
# [8500]	valid_0's auc: 0.90076
# [9000]	valid_0's auc: 0.900804
# [9500]	valid_0's auc: 0.900859
# [10000]	valid_0's auc: 0.900925
# [10500]	valid_0's auc: 0.90093
# [11000]	valid_0's auc: 0.900974
# [11500]	valid_0's auc: 0.900929
# [12000]	valid_0's auc: 0.900929
# [12500]	valid_0's auc: 0.900938
# [13000]	valid_0's auc: 0.900876
# [13500]	valid_0's auc: 0.900873
# [14000]	valid_0's auc: 0.900831
# Early stopping, best iteration is:
# [11115]	valid_0's auc: 0.900981
# 22
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.873884
# [1000]	valid_0's auc: 0.881318
# [1500]	valid_0's auc: 0.886185
# [2000]	valid_0's auc: 0.88996
# [2500]	valid_0's auc: 0.892729
# [3000]	valid_0's auc: 0.894967
# [3500]	valid_0's auc: 0.896631
# [4000]	valid_0's auc: 0.898145
# [4500]	valid_0's auc: 0.899216
# [5000]	valid_0's auc: 0.900058
# [5500]	valid_0's auc: 0.900712
# [6000]	valid_0's auc: 0.901269
# [6500]	valid_0's auc: 0.901731
# [7000]	valid_0's auc: 0.902039
# [7500]	valid_0's auc: 0.902321
# [8000]	valid_0's auc: 0.902457
# [8500]	valid_0's auc: 0.902582
# [9000]	valid_0's auc: 0.902681
# [9500]	valid_0's auc: 0.90269
# [10000]	valid_0's auc: 0.90267
# [10500]	valid_0's auc: 0.902631
# [11000]	valid_0's auc: 0.902613
# [11500]	valid_0's auc: 0.902619
# [12000]	valid_0's auc: 0.902631
# Early stopping, best iteration is:
# [9476]	valid_0's auc: 0.902707
# 23
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.869228
# [1000]	valid_0's auc: 0.87817
# [1500]	valid_0's auc: 0.883315
# [2000]	valid_0's auc: 0.887123
# [2500]	valid_0's auc: 0.88978
# [3000]	valid_0's auc: 0.891835
# [3500]	valid_0's auc: 0.893389
# [4000]	valid_0's auc: 0.894686
# [4500]	valid_0's auc: 0.895831
# [5000]	valid_0's auc: 0.896619
# [5500]	valid_0's auc: 0.897204
# [6000]	valid_0's auc: 0.897725
# [6500]	valid_0's auc: 0.89801
# [7000]	valid_0's auc: 0.898265
# [7500]	valid_0's auc: 0.898479
# [8000]	valid_0's auc: 0.898556
# [8500]	valid_0's auc: 0.898701
# [9000]	valid_0's auc: 0.8988
# [9500]	valid_0's auc: 0.898788
# [10000]	valid_0's auc: 0.898896
# [10500]	valid_0's auc: 0.898936
# [11000]	valid_0's auc: 0.898911
# [11500]	valid_0's auc: 0.898834
# [12000]	valid_0's auc: 0.898843
# [12500]	valid_0's auc: 0.898838
# [13000]	valid_0's auc: 0.898853
# [13500]	valid_0's auc: 0.898811
# Early stopping, best iteration is:
# [10782]	valid_0's auc: 0.898955
# 24
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.875313
# [1000]	valid_0's auc: 0.882416
# [1500]	valid_0's auc: 0.886023
# [2000]	valid_0's auc: 0.88949
# [2500]	valid_0's auc: 0.892019
# [3000]	valid_0's auc: 0.894069
# [3500]	valid_0's auc: 0.895518
# [4000]	valid_0's auc: 0.896973
# [4500]	valid_0's auc: 0.897967
# [5000]	valid_0's auc: 0.898727
# [5500]	valid_0's auc: 0.899389
# [6000]	valid_0's auc: 0.899843
# [6500]	valid_0's auc: 0.900111
# [7000]	valid_0's auc: 0.900457
# [7500]	valid_0's auc: 0.900711
# [8000]	valid_0's auc: 0.900906
# [8500]	valid_0's auc: 0.900984
# [9000]	valid_0's auc: 0.901097
# [9500]	valid_0's auc: 0.901149
# [10000]	valid_0's auc: 0.901167
# [10500]	valid_0's auc: 0.901136
# [11000]	valid_0's auc: 0.901188
# [11500]	valid_0's auc: 0.901246
# [12000]	valid_0's auc: 0.901253
# [12500]	valid_0's auc: 0.901206
# [13000]	valid_0's auc: 0.901189
# [13500]	valid_0's auc: 0.901138
# [14000]	valid_0's auc: 0.90115
# [14500]	valid_0's auc: 0.901159
# Early stopping, best iteration is:
# [11740]	valid_0's auc: 0.901263
# 25
# Training until validation scores don't improve for 3000 rounds.
# [500]	valid_0's auc: 0.872983
# [1000]	valid_0's auc: 0.880296
# [1500]	valid_0's auc: 0.884402
# [2000]	valid_0's auc: 0.888259
# [2500]	valid_0's auc: 0.890916
# [3000]	valid_0's auc: 0.893074
# [3500]	valid_0's auc: 0.894504
# [4000]	valid_0's auc: 0.895826
# [4500]	valid_0's auc: 0.896823
# [5000]	valid_0's auc: 0.897669
# [5500]	valid_0's auc: 0.898293
# [6000]	valid_0's auc: 0.898742
# [6500]	valid_0's auc: 0.899119
# [7000]	valid_0's auc: 0.899404
# [7500]	valid_0's auc: 0.899558
# [8000]	valid_0's auc: 0.899707
# [8500]	valid_0's auc: 0.899852
# [9000]	valid_0's auc: 0.899902
# [9500]	valid_0's auc: 0.899905
# [10000]	valid_0's auc: 0.89985
# [10500]	valid_0's auc: 0.899808
# [11000]	valid_0's auc: 0.899859
# [11500]	valid_0's auc: 0.89983
# [12000]	valid_0's auc: 0.899842
# Early stopping, best iteration is:
# [9279]	valid_0's auc: 0.899939

# %%
submission = pd.read_csv(path/'sample_submission.csv')
submission['target'] = result/counter
filename="{:%Y-%m-%d_%H_%M}_sub.csv".format(datetime.now())
submission.to_csv(filename, index=False)
